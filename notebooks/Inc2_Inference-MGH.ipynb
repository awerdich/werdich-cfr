# %% [markdown]
# ### Inference from a list of echo studies ###

# %%
import os
import glob
import pickle
import pandas as pd

# Custom imports
from werdich_cfr.tfutils.Modeltrainer import VideoTrainer
# Out:
# TensorFlow Version: 2.2.0

# %%
def read_model_dict(file):
    with open(file, 'rb') as f:
        model_dict = pickle.load(f)
    return model_dict

# Directories and data sets
cfr_data_root = os.path.normpath('/mnt/obi0/andreas/data/cfr')
meta_date = '201215'
location='MGH'
meta_dir = os.path.join(cfr_data_root, 'metadata_'+meta_date)
file_df_file = 'echo_'+location+'_npy_feather_files_'+meta_date+'.parquet'
view = 'a4c'

# echo list
#echo_list_dir = os.path.normpath('/mnt/obi0/andreas/data/cfr/predictions_echodata/SecondEchoGenetics')
#echo_list_filename = 'a4cname_'+location+'.txt'
#echo_file_list = list(echo_list.names.unique())
#print(f'Original file list: {len(echo_file_list)} files.')

echo_list_dir = os.path.join(cfr_data_root, 'predictions_echodata', 'FirstEchoEventsMGH')
echo_list_filename = 'MGH_2016-02-01_2016-11-30_FirstEcho.txt'
echo_list_file = os.path.join(echo_list_dir, echo_list_filename)
echo_list = pd.read_csv(echo_list_file, header='infer', sep='\t')
echo_df = echo_list.copy()
study_list = list(echo_list.study.unique())
echo_df.tail()
# Out:
#       Unnamed: 0  index  Unnamed: 0.1                                        study        date             PID
# 6138        7463   4359         20028  4e89a3810c1ecc_4903a58359a32c080dd7766c68ce  2016-11-30  4e89a3810c1ecc
# 6139        7465     36           133  48b5f810b76e6f_4903a58359a32c080c3eb4bd2ebd  2016-11-30  48b5f810b76e6f
# 6140        7467   6396         30092  4e8064dccf0d16_4903a58359a32c080c3cb1314ee3  2016-11-30  4e8064dccf0d16
# 6141        7469   2301          9343  490174538ff3cb_4903a58359a32c080c3914ad42ac  2016-11-30  490174538ff3cb
# 6142        7475   5182         23528  48bd8d5f15d84d_4903a58359a32c080c3fbe2c76f2  2016-11-30  48bd8d5f15d84d

# %%
fdir = os.path.normpath('/mnt/obi0/andreas/data/cfr/predictions_echodata/SecondEchoGenetics')
df = pd.read_parquet(os.path.join(fdir, 'a4cname_MGH_a4c.parquet'))
df.head()
# Out:
#                                             filename                                                dir                                        study      mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s       a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex         other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution    model             manufacturer max_view  sum_views
# 0  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...  /mnt/obi0/phi/echo/npyFiles/MGH/48b0/48b090129...  48b090129a7ecc_4903a582ec7227e72ca1a12db852  3517085 2017-03-29 10:52:45  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...      33.333              76.0        48.0  0.038599  0.038599  4.369181e-14  1.002213e-11  4.952000e-17  9.540701e-20  8.480631e-19
-10  1.070566e-08  0.999670  5.558679e-08  4.529298e-11  1.584545e-10  2.306140e-06  4.355476e-11  4.112836e-10  1.137845e-10  2.314202e-09  7.296246e-08  1.466954e-08  1.012915e-06  5.254900e-11  3.632735e-11  1.306045e-05  1.190157e-05  6.665559e-11  1.076000e-07  7.744462e-08  2.888699e-12  1.301527e-08      2016.0  20160411084709         MGH     iE33  Philips Medical Systems      a4c        1.0

# %%
# Create a reduced npy_feather files to speed up the metadata collections
file_df_file = 'echo_'+location+'_npy_feather_files_'+meta_date+'.parquet'
file_df = pd.read_parquet(os.path.join(meta_dir, file_df_file))

# Filter the meta data by the list of echos that we need
file_df_npy = file_df[file_df.study.isin(study_list)]
file_df_study_list = list(file_df_npy.study.unique())

print(f'Number of studies in echo list {len(study_list)}')
print(f'Number of studies found in .npy file list {len(file_df_study_list)}')
# What's missing?
missing_studies = list(set(study_list).difference(file_df_study_list))
print(f'Missing studies: {len(missing_studies)}')

# Save missing echo list
echo_list_file_missing = echo_list_filename.split('.')[0]+'_missing.parquet'
echo_list_missing = echo_list[echo_list.study.isin(missing_studies)]
echo_list_missing.to_parquet(os.path.join(echo_list_dir, echo_list_file_missing))

# Save the new list to collect the metadata
#file_df_file_pred = os.path.join(echo_list_dir, 'echo_BWH_npy_feather_files_eventechos_'+meta_date+'.parquet')
#file_df_study.to_parquet(file_df_file_pred)

print()
print(f'Number of patients in list with .npy data: {len(file_df_npy.mrn.unique())}')
print(f'Number of studies in list:                 {len(file_df_npy.study.unique())}')
# Out:
# Number of studies in echo list 6143
# Number of studies found in .npy file list 6117
# Missing studies: 26
#
# Number of patients in list with .npy data: 6117
# Number of studies in list:                 6117

# %%
# Join the echo list with the meta data and filter VIEWS!!!
meta_file = os.path.join(cfr_data_root, 'metadata_'+meta_date, 'echo_'+location+'_meta_'+meta_date+'.parquet')
meta_df_all_files = pd.read_parquet(meta_file)
meta_df_all_files = meta_df_all_files.loc[meta_df_all_files['mrn'] != 'DonWil']
meta_df_all_files = meta_df_all_files.loc[meta_df_all_files['mrn'] != '370001-057']

meta_df_all_files = meta_df_all_files.astype({'mrn': 'int64'})
print(len(meta_df_all_files.filename.unique()))
# Out:
# 2468600

# %%
# Load PET data
pet_echo_file = os.path.normpath('/mnt/obi0/phi/pet/pet_cfr/pets_with_echos_all.parquet')
pet_cols = ['mrn', 'pet_date', 'petmrn_identifier']
pet = pd.read_parquet(pet_echo_file)
pet = pet[pet_cols].dropna(how='all').drop_duplicates()
pet = pet.astype({'pet_date': 'datetime64[ns]'})
print(f'mrn-pet_date pairs {len(pet.petmrn_identifier.unique())}')
pet.head(2)
# Out:
# mrn-pet_date pairs 4136
#         mrn   pet_date    petmrn_identifier
# 0   7924277 2008-08-15   7924277_2008-08-15
# 1  12853099 2006-01-25  12853099_2006-01-25

# %%
meta_df.head()
# Out:
#                                             filename                                                dir                                      study     mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s           a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex     other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution model             manufacturer
# 0  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...
48b093000d7f_4903a580509f95b92b2105b5e972_Imag...  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...      69.111              19.0        96.0  0.037484  0.037484  3.103458e-11  2.158765e-09  3.463252e-12  1.363696e-09  8.869820e-09  8.140910e-13  6.538314e-12  9.812506e-10  1.857979e-12  5.038250e-13  1.256002e-12  2.829993e-10  8.921527e-11  1.429598e-11  1.000000  2.608026e-11  1.012110e-11  5.969460e-13  4.092798e-12  7.349879e-12  1.680008e-16  1.817957e-11  5.186810e-10  3.280693e-12  7.347609e-12  6.501483e-11  5.064302e-13      2015.0  20150816105225         BWH  iE33  Philips Medical Systems

# %%
# Filter the meta data by the echos we need
meta_df = meta_df_all_files[meta_df_all_files.study.isin(study_list)]
#meta_df = meta_df_all_files.copy()
#meta_df = meta_df[meta_df.filename.isin(echo_file_list)]

# Original file number
print(f'Number of files in meta data after echo filter: {len(meta_df.filename.unique())}')
print(f'Number of patients in meta data after echo filter: {len(meta_df.mrn.unique())}')

# Remove patients with PET studies
#meta_df_pet_patients = meta_df.loc[meta_df.mrn.isin(pet.mrn.unique())]
#print(f'Number of patients with PET measurements:       {len(meta_df_pet_patients.mrn.unique())}')
#meta_df = meta_df.loc[~meta_df.mrn.isin(pet.mrn.unique())]

print()
print(f'Patients in echo list after PET filter {len(meta_df.mrn.unique())}')
print(f'Studies in echo list after PET filter {len(meta_df.study.unique())}')

# Remove meta rows without view classification
meta_df = meta_df.loc[~meta_df.a4c.isnull()]
# Remove rows without frame_time
meta_df = meta_df.loc[~meta_df.frame_time.isnull()].reset_index(drop = True)

print()
print('After removal of rows without view clasification:')
print('Total number of patients in meta data {}'.format(len(meta_df.mrn.unique())))
print('Total number of studies {}'.format(len(meta_df.study.unique())))
print('Total number of files in meta data {}'.format(len(meta_df.filename.unique())))
# Out:
# Number of files in meta data after echo filter: 547966
# Number of patients in meta data after echo filter: 6116
#
# Patients in echo list after PET filter 6116
# Studies in echo list after PET filter 6116
#
# After removal of rows without view clasification:
# Total number of patients in meta data 6116
# Total number of studies 6116
# Total number of files in meta data 547952

# %%
view_dict = {'view_a2c': ['a2c', 'a2c_laocc', 'a2c_lvocc_s'],
             'view_a3c': ['a3c', 'a3c_laocc', 'a3c_lvocc_s'],
             'view_a4c': ['a4c', 'a4c_far', 'a4c_laocc', 'a4c_lvocc_s', 'a4c_rv', 'a4c_rv_laocc'],
             'view_plax': ['plax_far', 'plax_lac', 'plax_laz', 'plax_laz_ao', 'plax_plax'],
             'view_psax': ['psax_avz', 'psax_az', 'psax_mv', 'psax_pap'],
             'view_other': ['other', 'a5c', 'apex', 'rvinf', 'subcostal', 'suprasternal']}

# Get the maxiumum view classification score for each row
view_list = [item for sublist in view_dict.values() for item in sublist]
echo_meta_sum_views = meta_df.assign(max_view = meta_df[view_list].\
                                     idxmax(axis = 1))

# Make sure that we have all views in our list and for consistency: Sum up all view columns
echo_meta_sum_views = echo_meta_sum_views.assign(sum_views = echo_meta_sum_views[view_list].sum(axis=1))

print(f'Studies in data:     {len(echo_meta_sum_views.study.unique())}')
print(f'Total files:         {len(echo_meta_sum_views.filename.unique())}')

# Meta data with a4c videos
meta_df_a4c = echo_meta_sum_views[echo_meta_sum_views.max_view==view].reset_index(drop=True)

# Difference with original meta data list
studies_with_a4c = list(meta_df_a4c.study.unique())
studies_without_a4c = set(meta_df.study.unique()).difference(set(studies_with_a4c))
meta_df_noa4c = echo_meta_sum_views.loc[echo_meta_sum_views.study.isin(studies_without_a4c)]

print()
print(f'Studies in a4c data: {len(meta_df_a4c.study.unique())}')

print(f'Studies without a4c: {len(meta_df_noa4c.study.unique())}')

print(f'Total files:         {len(meta_df_a4c.filename.unique())}')
print(f'Total patients:      {len(meta_df_a4c.mrn.unique())}')
# Out:
# Studies in data:     6116
# Total files:         547952
#
# Studies in a4c data: 5873
# Studies without a4c: 243
# Total files:         27534
# Total patients:      5873

# %%
meta_a4c_filename = echo_list_filename.split('.')[0] + '_'+view+'.parquet'
print(meta_a4c_filename)
meta_a4c_file = os.path.join(echo_list_dir, meta_a4c_filename)
meta_df_a4c.to_parquet(meta_a4c_file)

# Save the list of studies that do not have a4c views
no_a4c_list_name = echo_list_filename.split('.')[0]+'_noA4C.parquet'
meta_df_noa4c.to_parquet(os.path.join(echo_list_dir, no_a4c_list_name))
print(f'Studies without A4C views: {len(meta_df_noa4c["study"].unique())}')

meta_df_a4c.head(2)
# Out:
# MGH_2016-02-01_2016-11-30_FirstEcho_a4c.parquet
# Studies without A4C views: 243
#                                             filename                                                dir                                        study      mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s  a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex         other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution    model             manufacturer max_view  sum_views
# 0  42682402b3c10b_4903a5835833332194704a2d2704_Im...  /mnt/obi0/phi/echo/npyFiles/MGH/4268/42682402b...  42682402b3c10b_4903a5835833332194704a2d2704  9993883 2016-04-21 15:22:29  42682402b3c10b_4903a5835833332194704a2d2704_Im...  42682402b3c10b_4903a5835833332194704a2d2704_Im...      19.971             171.0        56.0  0.034504  0.034504  1.465253e-12  3.558658e-13  1.362834e-15  1.393748e-16  1.636494e-18  1.667692e-14  1.0  8.258046e-13  1.607764e-14  2.619088e-14  1.138890e-12  3.604244e-15  2.574658e-15  1.022173e-14  2.244932e-12  7.082282e-14  1.167836e-13  9.788465e-14  1.086437e-17  7.009227e-15  1.890788e-15  4.911013e-15  1.873706e-15  1.443030e-15  7.439623e-16  1.241389e-17  1.118388e-16      2016.0  20160421152229         MGH  EPIQ 7C  Philips Medical Systems      a4c        1.0
# 1  42682402b3c10b_4903a5835833332194704a2d2704_Im...  /mnt/obi0/phi/echo/npyFiles/MGH/4268/42682402b...  42682402b3c10b_4903a5835833332194704a2d2704  9993883 2016-04-21 15:22:29  42682402b3c10b_4903a5835833332194704a2d2704_Im...  42682402b3c10b_4903a5835833332194704a2d2704_Im...      12.792             266.0        52.0  0.034504  0.034504  1.429675e-10  1.209982e-10  3.761207e-14  5.618406e-14  6.433915e-16  1.283747e-14  1.0  2.415003e-11  4.252329e-13  1.217886e-12  8.072933e-10  1.759033e-14  9.819330e-12  9.826575e-13  5.669199e-12  1.286879e-12  2.241067e-10  1.932871e-11  4.753124e-14  1.362445e-14  6.338415e-14  8.429518e-13  1.295554e-14  6.466672e-14  6.680162e-17  8.828239e-15  5.401290e-15      2016.0  20160421152229         MGH  EPIQ 7C  Philips Medical Systems      a4c        1.0

# %%
print(f'Patients in new meta data: {len(meta_df_a4c["mrn"].unique())}')
print(f'Studies in meta data:      {len(meta_df_a4c["study"].unique())}')
print(f'Videos:                    {len(meta_df_a4c["filename"].unique())}')
# Out:
# Patients in new meta data: 5873
# Studies in meta data:      5873
# Videos:                    27534

# %%
print(len(echo_df.study.unique()))
print(len(meta_df_a4c.study.unique()))
# Out:
# 6143
# 26571

# %%
# Concatenate MGH and BWH data
df_mgh = pd.read_parquet(os.path.join(echo_list_dir, 'a4cname_MGH_a4c.parquet'))
df_bwh = pd.read_parquet(os.path.join(echo_list_dir, 'a4cname_BWH_a4c.parquet'))
print(f'MGH files {len(df_mgh.filename.unique())}')
print(f'BWH files {len(df_bwh.filename.unique())}')
df = pd.concat([df_mgh, df_bwh], ignore_index=True).reset_index(drop=True)
fn = 'a4cname_MGHBWH_a4c.parquet'
df.to_parquet(os.path.join(echo_list_dir, fn))
print(f'Total files {len(df.filename.unique())}')
df.head()
# Out:
# MGH files 13273
# BWH files 26537
# Total files 39810
#                                             filename                                                dir                                        study      mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s       a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex         other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution    model             manufacturer max_view  sum_views
# 0  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...  /mnt/obi0/phi/echo/npyFiles/MGH/48b0/48b090129...  48b090129a7ecc_4903a582ec7227e72ca1a12db852  3517085 2017-03-29 10:52:45  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...  48b090129a7ecc_4903a582ec7227e72ca1a12db852_Im...      33.333              76.0        48.0  0.038599  0.038599  4.369181e-14  1.002213e-11  4.952000e-17  9.540701e-20  8.480631e-19  3.362204e-15  1.000000  1.380723e-14  1.235565e-16  1.717246e-15  1.413478e-16  1.533292e-16  2.999292e-17  3.079603e-17  2.827710e-22  6.419594e-17  4.401530e-16  2.819618e-16  3.035525e-18  6.578000e-17  9.705355e-16  1.937740e-14  8.963561e-17  1.988039e-15  1.589031e-20  2.990445e-20  2.887505e-18      2017.0  20170329105245         MGH  EPIQ 7C  Philips Medical Systems      a4c        1.0
# 0    nondefect_a4c_dgx-1_rest_mbf_unaff     rest_mbf_unaff    100  /mnt/obi0/andreas/data/cfr/log/nondefect_a4c_d...   0.343776  7.655502e-26  0.350960  6.191784e-27        881  nondefect  a4c  dgx-1
# 1  nondefect_a4c_dgx-1_stress_mbf_unaff   stress_mbf_unaff    100  /mnt/obi0/andreas/data/cfr/log/nondefect_a4c_d...   0.446963  1.734637e-44  0.440022  5.112244e-43        881  nondefect  a4c  dgx-1
# 2    nondefect_a4c_dgx-1_unaffected_cfr     unaffected_cfr    100  /mnt/obi0/andreas/data/cfr/log/nondefect_a4c_d...   0.226273  1.083594e-11  0.263326  1.934262e-15        881  nondefect  a4c  dgx-1
# 3     global_a4c_gpu2_stress_global_mbf  stress_global_mbf    150  /mnt/obi0/andreas/data/cfr/log/global_a4c_gpu2...   0.521974  1.406801e-74  0.532282  5.110090e-78       1052     global  a4c   gpu2
# 4      global_a4c_dgx-1_rest_global_mbf    rest_global_mbf    150  /mnt/obi0/andreas/data/cfr/log/global_a4c_dgx-...   0.444414  3.753792e-52  0.458937  6.343615e-56       1052     global  a4c  dgx-1
# 5       global_a4c_gpu2_global_cfr_calc    global_cfr_calc     50  /mnt/obi0/andreas/data/cfr/log/global_a4c_gpu2...   0.325327  2.339397e-27  0.354585  1.593943e-32       1052     global  a4c   gpu2

# %%
# Load disqualified files after predictions
dis_df_file_BWH = 'BWH_2015-06-01_2015-11-30_FirstEcho_a4c_disqualified.parquet'
dis = pd.read_parquet(os.path.join(echo_list_dir, dis_df_file_BWH))
print(dis.err.unique())
dis.head(2)
# Out:
# ['video_len' 'frame_rate' 'deltaXY']
#                                             filename                                                dir                                      study     mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s       a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex         other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution model             manufacturer max_view  sum_views        err
# 0  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...  /mnt/obi0/phi/echo/npyFiles/BWH/48b0/48b093000...  48b093000d7f_4903a580509f95b92b2105b5e972  352917 2015-08-16 10:52:25  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...      33.333              38.0        98.0  0.041843  0.041843  1.029911e-12  1.078118e-10  6.555025e-11  4.524656e-13  1.383462e-11  8.704672e-12  1.000000  3.328544e-09  6.031483e-12  1.011731e-13  1.491283e-09  2.553013e-13  2.601509e-10  7.555116e-14  1.384863e-12  1.448429e-12  4.486194e-12  5.324471e-12  4.132527e-13  1.562419e-16  9.941389e-12  6.200402e-10  3.362825e-12  3.102536e-10  3.127262e-11  7.137986e-16  4.884658e-12      2015.0  20150816105225         BWH  iE33  Philips Medical Systems      a4c        1.0  video_len
# 1  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...  /mnt/obi0/phi/echo/npyFiles/BWH/48b0/48b093000...  48b093000d7f_4903a580509f95b92b2105b5e972  352917 2015-08-16 10:52:25  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...  48b093000d7f_4903a580509f95b92b2105b5e972_Imag...      33.333              38.0        96.0  0.041843  0.041843  4.055386e-12  6.216032e-12  3.634575e-11  6.060132e-12  1.590235e-10  6.489257e-12  0.999999  6.272859e-11  1.488713e-11  1.422675e-13  9.233230e-09  2.933806e-11  1.076182e-10  6.407318e-13  4.470310e-16  2.696358e-12  2.048425e-13  6.161614e-12  1.317816e-13  3.299598e-15  1.571574e-10  1.025484e-06  1.807344e-12  3.956003e-10  1.070398e-11  5.639570e-15  1.382021e-10      2015.0  20150816105225         BWH  iE33  Philips Medical Systems      a4c        1.0  video_len

# %%
print(f'Disqualified videos: {len(dis.filename.unique())}')
print(f'From {len(dis.mrn.unique())} patients')
# Out:
# Disqualified videos: 4416
# From 1890 patients

# %%
echo_df_file_BWH = 'BWH_2015-06-01_2015-11-30_FirstEcho_a4c.parquet'
echo_list_filename = 'BWH_2015-06-01_2015-11-30_FirstEcho.txt'

# %%
len(dis.mrn.unique())
# Out:
# 1890

# %%
echo_list_file = os.path.join(echo_list_dir, echo_list_filename)
echo_list = pd.read_csv(echo_list_file, header='infer', sep='\t')
echo_file_list_BWH = list(echo_list.names.unique())
dis_df_BWH = pd.read_parquet(os.path.join(echo_list_dir, dis_df_file_BWH))
echo_df_BWH = pd.read_parquet(os.path.join(echo_list_dir, echo_df_file_BWH))
print('BWH')
print(f'Files in original list:       {len(echo_file_list_BWH)}')
print(f'Files with .npy and metadata: {len(echo_df_BWH.filename.unique())}')
print(f'Disqualified files:           {len(dis_df_BWH.filename.unique())}')

dis_df_file_MGH = 'a4cname_MGH_a4c_disqualified.parquet'
echo_df_file_MGH = 'a4cname_MGH_a4c.parquet'
echo_list_filename = 'a4cname_MGH.txt'
echo_list_file = os.path.join(echo_list_dir, echo_list_filename)
echo_list = pd.read_csv(echo_list_file, header='infer', sep='\t')
echo_file_list_MGH = list(echo_list.names.unique())

dis_df_MGH = pd.read_parquet(os.path.join(echo_list_dir, dis_df_file_MGH))
echo_df_MGH = pd.read_parquet(os.path.join(echo_list_dir, echo_df_file_MGH))

print()
print('MGH')
print(f'Files in original list:       {len(echo_file_list_MGH)}')
print(f'Files with .npy and metadata: {len(echo_df_MGH.filename.unique())}')
print(f'Disqualified files:           {len(dis_df_MGH.filename.unique())}')

# %% [markdown]
# #### Special: Concatenate predictions ####

# %%
pred_dir = os.path.join(cfr_data_root, 'predictions_echodata', 'SecondEchoGenetics', 'cfr_models_30fps')
pred_dir_round2 = os.path.join(pred_dir, 'disqualified_deltaX')
pred_dir_concat = os.path.join(pred_dir, 'concatenated')
model_df = pd.read_parquet(os.path.join(pred_dir, 'cfr_correlations_bestmodels_30FPS.parquet')).reset_index(drop=True)
model_list = sorted(list(model_df.model_name.unique()))
print(*model_list, sep='\n')

for model in model_list:
    concat_filename = model+'_con.parquet'
    df1 = pd.read_parquet(os.path.join(pred_dir, model+'.parquet'))
    df2 = pd.read_parquet(os.path.join(pred_dir_round2, model+'.parquet'))
    df = pd.concat([df1, df2], ignore_index=True).reset_index(drop=True)
    df.to_parquet(os.path.join(pred_dir_concat, concat_filename))
    print(concat_filename)
# Out:
# cfr_a4c_dgx-1_fc1_global_cfr_calc
# cfr_a4c_dgx-1_fc1_rest_global_mbf
# cfr_a4c_dgx-1_fc1_stress_global_mbf
# mbf_ammonia_a4c_dgx-1_fc1_rest_global_mbf
# mbf_ammonia_a4c_dgx-1_fc1_stress_global_mbf
# mbf_rubidium_a4c_dgx-1_fc1_rest_global_mbf
# mbf_rubidium_a4c_dgx-1_fc1_stress_global_mbf
# cfr_a4c_dgx-1_fc1_global_cfr_calc_con.parquet
# cfr_a4c_dgx-1_fc1_rest_global_mbf_con.parquet
# cfr_a4c_dgx-1_fc1_stress_global_mbf_con.parquet
# mbf_ammonia_a4c_dgx-1_fc1_rest_global_mbf_con.parquet
# mbf_ammonia_a4c_dgx-1_fc1_stress_global_mbf_con.parquet
# mbf_rubidium_a4c_dgx-1_fc1_rest_global_mbf_con.parquet
# mbf_rubidium_a4c_dgx-1_fc1_stress_global_mbf_con.parquet

# %%
df = pd.read_parquet(os.path.join(pred_dir_concat, 'cfr_a4c_dgx-1_fc1_global_cfr_calc_con.parquet'))
print(df1.shape)
print(df2.shape)
print(df.shape)
# Out:
# (39701, 51)
# (109, 52)
# (39810, 52)

# %%
# Out:
#                                                 filename     model_output dataset  predictions                         model_name                                      checkpoint                                                dir                                          study       mrn            datetime                                          file_base                                         identifier  frame_time  number_of_frames  heart_rate    deltaX    deltaY           a2c     a2c_laocc   a2c_lvocc_s           a3c     a3c_laocc   a3c_lvocc_s       a4c       a4c_far     a4c_laocc   a4c_lvocc_s        a4c_rv  a4c_rv_laocc           a5c          apex         other      plax_far      plax_lac      plax_laz   plax_laz_ao     plax_plax      psax_avz       psax_az       psax_mv      psax_pap         rvinf     subcostal  suprasternal  year_month study_full_time institution          model manufacturer max_view  sum_views      err
# 39805  4b7f0b164feb8195_4903a58c1bce1212c86939843ae2_...  global_cfr_calc     cfr     1.635862  cfr_a4c_dgx-1_fc1_global_cfr_calc  cfr_a4c_dgx-1_fc1_global_cfr_calc_chkpt_150.h5  /mnt/obi0/phi/echo/npyFiles/BWH/4b7f/4b7f0b164...  4b7f0b164feb8195_4903a58c1bce1212c86939843ae2  04781852 2019-01-14 14:08:34  4b7f0b164feb8195_4903a58c1bce1212c86939843ae2_...  4b7f0b164feb8195_4903a58c1bce1212c86939843ae2_...      20.454             178.0        60.0 -0.027692  0.027692  3.771694e-11  7.430399e-14  2.600897e-15  2.822536e-15  8.917752e-18  1.851245e-14  1.000000  8.109012e-14  8.301014e-17  5.468927e-13  2.354303e-12  2.473872e-15  4.135979e-14  3.848450e-17  1.279134e-11  2.776904e-13  7.356319e-15  1.953404e-10  1.111036e-16  5.972073e-15  7.385621e-14  1.231339e-16  2.842566e-17  2.839391e-13  1.683895e-17  2.032759e-20  1.154025e-17      2019.0  20190114140834         BWH  ACUSON SC2000      SIEMENS      a4c        1.0  deltaXY
# 39806  4b7f0cd3bca66d19_4903a580509e8af3e8b7e8c36269_...  global_cfr_calc     cfr     1.957031  cfr_a4c_dgx-1_fc1_global_cfr_calc  cfr_a4c_dgx-1_fc1_global_cfr_calc_chkpt_150.h5  /mnt/obi0/phi/echo/npyFiles/BWH/4b7f/4b7f0cd3b...  4b7f0cd3bca66d19_4903a580509e8af3e8b7e8c36269  04067765 2015-09-16 13:48:20  4b7f0cd3bca66d19_4903a580509e8af3e8b7e8c36269_...  4b7f0cd3bca66d19_4903a580509e8af3e8b7e8c36